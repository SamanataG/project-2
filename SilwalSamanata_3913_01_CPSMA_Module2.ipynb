# %% [markdown]
# Project Part #2 : CPSMA 3133 Discrete Mathematics
#
# Relations and Functions
#
# # Samanata Silwal

# %% [markdown]
# #1 FUNCTION

# %% [markdown]
# In a program, a function is a section of code that carries out a certain set of activities.
#
# Your code may be divided up into functions. You decide how to divide your code into different functions, but logically each function should be assigned a certain task.The name, return type, and parameters of a function are all listed in the declaration of that function. A function definition offers the actual body of the function.

# %% [markdown]
# For example:

# %%
def test_function():
  print("My name is Samanata Silwal.")

# %%
test_function()
# Out:
# My name is Samanata Silwal.

# %% [markdown]
#  In the above illustrative example:
#
#
# *   Defined with the def keyword is the function test function().
# *   Invoking a function is as simple as entering its name in parentheses ().
# *   The following syntax is used to pass input parameters and get a value back from a function:

# %% [markdown]
# *def <function_name>( parameter list ) *
# *   #body of function *

# %%
def addition(a,b):#function for adding two numbers
    add=a+b;
    return add; #return value
p=45  #declaration of variables
q=85
print("The sum of two numbers is :",addition(p,q))
# Out:
# The sum of two numbers is : 130

# %% [markdown]
# I am using refrence from States and city name for my project beacuse I love traveling few of city I have been through last year.

# %% [markdown]
# ![Map-of-United-States-of-America-with-State-names-1.webp](data:image/webp;base64,...)

# %%
import numpy as npy

def United(x):
   return npy.sin(x) + x + x * npy.sin(x)

# %%
United(20)
# Out:
# 39.171850265280185

# %% [markdown]
# To plot the graph, use the procedure below:
#
#
#
# *   Generate x data points with numpy.
# *   Plot x using the plot() function and run the test (x).
# *   For the figure to be displayed, use the show() function.

# %%
import numpy as npy

from matplotlib import pyplot as p

p.rcParams["figure.figsize"] = [7.50, 3.50]
p.rcParams["figure.autolayout"] = True

def gaussian(a):
   return npy.sin(a) + a + a * npy.sin(a)

a = npy.linspace(-20, 20, 200) #I already explained the -20 and 20 but the 200 needs to be there and should just stay 200. 

p.plot(a, gaussian(a), color='blue')

p.show()

# %% [markdown]
# My function is not bijective on the graphed domain. But is on the interval  [0,20] . It is unto from  (0,39.17) .

# %% [markdown]
# #2 DICTIONARIES

# %% [markdown]
# In what follows, I'll define a dictionary that links sets X and Y  together.

# %%
X = ['Dallas', 'Austin', 'ADA', 'Okland', 'Pullman', 'New Bern', 'San-Jose']
Y = ['Alaska', 'San-Jose', 'Tampa', 'ADA', 'Pullman', 'St-Louis']

dictionary = dict({x:y for x,y in zip(X, Y)})

# %%
dictionary
# Out:
# {'Dallas': 'Alaska',
#  'Austin': 'San-Jose',
#  'ADA': 'Tampa',
#  'Okland': 'ADA',
#  'Pullman': 'Pullman',
#  'New Bern': 'St-Louis'}

# %%
actualDictionary = dict({'New Bern':'Alaska','Pullman':'Ada', 'Ada':'Pullman'})

#the only one that really makes sence is St-louis and New Bern

# %%
newlist2 = [actualDictionary.get(x,x) for x in X]

# %%
newlist2
# Out:
# ['Dallas', 'Austin', 'ADA', 'Okland', 'Ada', 'Alaska', 'San-Jose']

# %% [markdown]
# The list was altered as a result of this. This dictionary serves a purpose; I only make a few changes and nothing duplicates itself. I don't believe dictionaries are capable of doing that. Since it is not upon, it cannot be dual.
#
#
# New Bern visits Alaska but does not return, hence the relationship is not an endo relation but it is not symmetric. Since, I don't transfer Austin back to Austin, it is not reflexive. Because there isn't a counter example, it is transitive. Basically, it is transitive since I never mapped anything from the range into the domain.

# %% [markdown]
# According to my dictionary relation, there are symmetric relation but there is neither reflective nor transitive relation. As per reflective element it should be related to within such as (Pullman':'Ada', 'Ada':'Pullman').Each relation would need to contain the opposite relation in order to be symmetric. For instance('St-Louis', New Bern') is a symmetrical . It is not transitive. It is not an equivalence relation.
#
#
# This project got me with all the graphing points Up to down down to up.
#
#
# I mean going easy than got stuck for hours and hours and got back again and again took me while to get back.
